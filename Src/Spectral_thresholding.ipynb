# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from SpectralThresholding import SpectralThresholding

# %%
apple_img = cv.imread("images/apple.png", cv.IMREAD_GRAYSCALE)
plt.imshow(apple_img, cmap='gray')

# %%
thresholdImg = SpectralThresholding().doThresholding(apple_img)
plt.imshow(thresholdImg, cmap='gray')

# %%
img = cv.imread('images/dots2.jpg', cv.IMREAD_GRAYSCALE)
thresholdImg = SpectralThresholding().doThresholding(img)
plt.imshow(thresholdImg, cmap='gray')
